# %% [markdown]
# # Krish naik video 2 Feature Selection
# link: https://www.youtube.com/watch?v=FndwYNcVe0U&list=PLZoTAELRMXVPgjwJ8VyRoqmfNs2CJwhVH&index=2

# %%
# !wget https://raw.githubusercontent.com/scikit-learn/scikit-learn/main/sklearn/datasets/data/boston_house_prices.csv
# Out:
# --2024-03-22 15:14:20--  https://raw.githubusercontent.com/scikit-learn/scikit-learn/main/sklearn/datasets/data/boston_house_prices.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34742 (34K) [text/plain]
# Saving to: ‘boston_house_prices.csv’
#
# boston_house_prices 100%[===================>]  33.93K  --.-KB/s    in 0.02s
#
# 2024-03-22 15:14:20 (2.12 MB/s) - ‘boston_house_prices.csv’ saved [34742/34742]

# %%
## importing the libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('boston_house_prices.csv')
df.head()
# Out:
#        506  13 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0     CRIM  ZN      INDUS       CHAS        NOX         RM        AGE
# 1  0.00632  18       2.31          0      0.538      6.575       65.2
# 2  0.02731   0       7.07          0      0.469      6.421       78.9
# 3  0.02729   0       7.07          0      0.469      7.185       61.1
# 4  0.03237   0       2.18          0      0.458      6.998       45.8
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0        DIS        RAD        TAX     PTRATIO           B       LSTAT
# 1       4.09          1        296        15.3       396.9        4.98
# 2     4.9671          2        242        17.8       396.9        9.14
# 3     4.9671          2        242        17.8      392.83        4.03
# 4     6.0622          3        222        18.7      394.63        2.94
#
#   Unnamed: 13
# 0        MEDV
# 1          24
# 2        21.6
# 3        34.7
# 4        33.4

# %%
df.iloc[0].values
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV'], dtype=object)

# %%
df.columns = df.iloc[0].values

# %%
df.head()
# Out:
#       CRIM  ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0     CRIM  ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO
# 1  0.00632  18   2.31     0  0.538  6.575  65.2    4.09    1  296     15.3
# 2  0.02731   0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 3  0.02729   0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 4  0.03237   0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0       B  LSTAT  MEDV
# 1   396.9   4.98    24
# 2   396.9   9.14  21.6
# 3  392.83   4.03  34.7
# 4  394.63   2.94  33.4

# %%
df.drop(0, inplace=True)

# %%
df.head()
# Out:
#       CRIM  ZN INDUS CHAS    NOX     RM   AGE     DIS RAD  TAX PTRATIO  \
# 1  0.00632  18  2.31    0  0.538  6.575  65.2    4.09   1  296    15.3
# 2  0.02731   0  7.07    0  0.469  6.421  78.9  4.9671   2  242    17.8
# 3  0.02729   0  7.07    0  0.469  7.185  61.1  4.9671   2  242    17.8
# 4  0.03237   0  2.18    0  0.458  6.998  45.8  6.0622   3  222    18.7
# 5  0.06905   0  2.18    0  0.458  7.147  54.2  6.0622   3  222    18.7
#
#         B LSTAT  MEDV
# 1   396.9  4.98    24
# 2   396.9  9.14  21.6
# 3  392.83  4.03  34.7
# 4  394.63  2.94  33.4
# 5   396.9  5.33  36.2

# %%
X = df.drop("MEDV", axis=1)
y = df["MEDV"]

# %%
X.head()
# Out:
#       CRIM  ZN INDUS CHAS    NOX     RM   AGE     DIS RAD  TAX PTRATIO  \
# 1  0.00632  18  2.31    0  0.538  6.575  65.2    4.09   1  296    15.3
# 2  0.02731   0  7.07    0  0.469  6.421  78.9  4.9671   2  242    17.8
# 3  0.02729   0  7.07    0  0.469  7.185  61.1  4.9671   2  242    17.8
# 4  0.03237   0  2.18    0  0.458  6.998  45.8  6.0622   3  222    18.7
# 5  0.06905   0  2.18    0  0.458  7.147  54.2  6.0622   3  222    18.7
#
#         B LSTAT
# 1   396.9  4.98
# 2   396.9  9.14
# 3  392.83  4.03
# 4  394.63  2.94
# 5   396.9  5.33

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=0.3,
    random_state=42
)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((354, 13), (152, 13), (354,), (152,))
